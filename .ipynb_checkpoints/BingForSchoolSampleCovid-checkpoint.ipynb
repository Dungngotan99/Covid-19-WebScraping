# %%
import requests
import pandas as pd
import time

# %%
key = '80d9de17fa194ad2804602599b9601be'
endpoint = "https://api.cognitive.microsoft.com/bing/v7.0/search"
headers = {"Ocp-Apim-Subscription-Key": key}
params = {"q": '', "textDecorations": False, "textFormat": "HTML", 'count': 3,'responseFilter':'Webpages',}

# %%
df = pd.read_csv('district_sample_web_catalog - schools_cleaned.csv', index_col = 0).astype(
'object')
df2 = pd.read_csv('school_sample_covid_cleaned.csv', index_col = 0).astype('object')
df2 = df2.drop(columns = ['district','state','school','school_sample'])
df = df.merge(df2,how = 'inner',on = ['cleaned'])
df['zip']=df['zip'].apply(lambda x: str(x).zfill(5))

# %%
#Currently created manually, might be better once we can run a lot of testing to just filter out domains that come up frequently
url_filters = ['facebook.com','elementaryschools.org','usnews.com','greatschools.org',
              'niche.com','schooldigger.com','wikipedia.org','publicschoolreview.com','areavibes.com',
               'realtor.com','high-schools.com','redfin.com','realtor.com','zillow.com']
database_sites = ['greatschools.org','niche.com','schooldigger.com','elementaryschools.org','publicschoolreview.com']

# %%
def name_city(row):
    search_term = row['cleaned']
    if row['city'] not in search_term:
        search_term += ' '+ row['city']
    return search_term

def name(row):
    search_term = row['cleaned']
    return search_term

def name_city_zip(row):
    search_term = row['cleaned']
    if row['city'] not in search_term:
        search_term += ' '+ row['city']
    search_term += ' ' + row['zip']
    return search_term

def name_zip(row):
    search_term = row['cleaned']
    search_term += ' ' + row['zip']
    return search_term

# %%
def whitelisted(url_string):
    return any(website in url_string for website in url_filters)
def is_database(url_string):
    return any(website in url_string for website in databse_sites.values())

# %%
def get_url(row,searchTermFunc):
    params['q'] = searchTermFunc(row)
    response = requests.get(endpoint, headers=headers, params=params)
    search_results = response.json()
    urls = [search_results['webPages']['value'][i]['url'] for i in range(3)]
    #To prevent calling the API too many times per second
    #time.sleep(.5)
    if not any(check in urls[0] for check in url_filters):
        return [urls[0],None]
    for url in urls:
        if any(check in url for check in database_sites):
            return [None,url]
    return [None,None]

# %%
# %%timeit -r1 -n1
#Be careful running this as it performs as many API calls as the test_schools_df and we have limited amounts of calls
results = df.apply(get_url,args = [name_city],axis=1)
df['name_city_url'],null = map(list, zip(*results)) 
results = df.apply(get_url,args = [name_city_zip],axis=1)
df['name_city_zip_url'],null = map(list, zip(*results))
results = df.apply(get_url,args = [name],axis=1)
df['name_url'],null = map(list, zip(*results))
results = df.apply(get_url,args = [name],axis=1)
df['name_zip_url'],null = map(list, zip(*results))
# Out:
# 3min 6s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
df.head()
# Out:
#                         district state                             school  \
# 0            Adelanto Elementary    CA             Eagle Ranch Elementary
# 1            Adelanto Elementary    CA                Adelanto Elementary
# 2            Adelanto Elementary    CA  Melva Davis Academy Of Excellence
# 3            Adelanto Elementary    CA                  Mesa Linda Middle
# 4  Baltimore City Public Schools    MD         Hamilton Elementary/Middle
#
#         level                                school_link  \
# 0  Elementary              https://www.aesd.net/ers/home
# 1  Elementary              https://www.aesd.net/aes/home
# 2      Middle               https://www.aesd.net/13/Home
# 3      Middle             https://www.aesd.net/mlms/home
# 4  Elementary  https://www.hamiltonelementarymiddle.org/
#
#   different from district? learning platform? learning platform_name  \
# 0                      0.0                Nan                    Nan
# 1                      0.0                Nan                    Nan
# 2                      0.0                Nan                    Nan
# 3                      0.0                Nan                    Nan
# 4                      Nan                Nan                    Nan
#
#   date collected  pdf  ... collected by                            cleaned  \
# 0     03/30/2020    0  ...        Cathy      Eagle Ranch Elementary School
# 1     03/30/2020    0  ...        Cathy         Adelanto Elementary School
# 2     03/30/2020    0  ...        Cathy  Melva Davis Academy Of Excellence
# 3     03/30/2020    0  ...        Cathy           Mesa Linda Middle School
# 4     03/30/2020  Nan  ...        Cathy  Hamilton Elementary/Middle School
#
#           city                 county                  address    zip  \
# 0     Adelanto  San Bernardino County  12545 Eagle Ranch Pkwy.  92301
# 1     Adelanto  San Bernardino County       17931 Jonathan St.  92301
# 2  Victorville  San Bernardino County        15831 Diamond Rd.  92394
# 3  Victorville  San Bernardino County     13001 Mesa Linda Rd.  92392
# 4    Baltimore         Baltimore City      6101 Old Harford Rd  21214
#
#                                       name_city_url  \
# 0                          http://www.ers.aesd.net/
# 1                              http://www.aesd.net/
# 2                     http://www.aesd.net/mdae/home
# 3                         http://www.mlms.aesd.net/
# 4  https://www.baltimorecityschools.org/schools/236
#
#                            name_city_zip_url  \
# 0                   http://www.ers.aesd.net/
# 1                   http://www.aes.aesd.net/
# 2              http://www.aesd.net/mdae/home
# 3                  http://www.mlms.aesd.net/
# 4  https://www.hamiltonelementarymiddle.org/
#
#                                     name_url  \
# 0                   http://www.ers.aesd.net/
# 1                       http://www.aesd.net/
# 2              http://www.aesd.net/mdae/home
# 3                  http://www.mlms.aesd.net/
# 4  https://www.hamiltonelementarymiddle.org/
#
#                                 name_zip_url
# 0                   http://www.ers.aesd.net/
# 1                       http://www.aesd.net/
# 2              http://www.aesd.net/mdae/home
# 3                  http://www.mlms.aesd.net/
# 4  https://www.hamiltonelementarymiddle.org/
#
# [5 rows x 21 columns]

# %%
df = pd.read_csv('tests_scored.csv', index_col = 0)

# %%
df.tail()
# Out:
#               district state                      school       level  \
# 107  Yuba City Unified    CA      King Avenue Elementary  Elementary
# 108  Yuba City Unified    CA            Barry Elementary  Elementary
# 109  Yuba City Unified    CA  Albert Powell Continuation        High
# 110  Yuba City Unified    CA              Yuba City High        High
# 111  Yuba City Unified    CA          Gray Avenue Middle      Middle
#
#                                            school_link  \
# 107  http://www.ycusd.org/announcements/?capostid=2...
# 108  http://www.ycusd.org/announcements/?capostid=2...
# 109  http://www.ycusd.org/announcements/?capostid=2...
# 110  http://ychs.ycusd.org/documents/Message%20from...
# 111  http://www.ycusd.org/announcements/?capostid=2...
#
#     different from district? learning platform? learning platform_name  \
# 107                        0                Nan                    Nan
# 108                        0                Nan                    Nan
# 109                        0                Nan                    Nan
# 110                        1                Nan                    Nan
# 111                        0                Nan                    Nan
#
#     date collected pdf  ...          address    zip            name_city_url  \
# 107     03/30/2020   0  ...    630 King Ave.  95991   http://king.ycusd.org/
# 108     03/30/2020   0  ...   1255 Barry Rd.  95991  http://barry.ycusd.org/
# 109     03/30/2020   0  ...  1875 Clark Ave.  95991   http://aphs.ycusd.org/
# 110     03/30/2020   1  ...        850 B St.  95991   http://ychs.ycusd.org/
# 111     03/30/2020   0  ...    808 Gray Ave.  95991   http://gray.ycusd.org/
#
#     name_city_score        name_city_zip_url name_city_zip_score  \
# 107             1.0   http://king.ycusd.org/                1.00
# 108             1.0  http://barry.ycusd.org/                1.00
# 109             1.0   http://aphs.ycusd.org/                1.00
# 110             1.0    http://www.ycusd.org/                0.01
# 111             1.0   http://gray.ycusd.org/                1.00
#
#                     name_url name_score             name_zip_url  \
# 107   http://king.ycusd.org/        1.0   http://king.ycusd.org/
# 108  http://barry.ycusd.org/        1.0  http://barry.ycusd.org/
# 109   http://aphs.ycusd.org/        1.0   http://aphs.ycusd.org/
# 110   http://ychs.ycusd.org/        1.0   http://ychs.ycusd.org/
# 111   http://gray.ycusd.org/        1.0   http://gray.ycusd.org/
#
#     name_zip_score
# 107            1.0
# 108            1.0
# 109            1.0
# 110            1.0
# 111            1.0
#
# [5 rows x 25 columns]

# %%
cols = ['name_city_score','name_score','name_city_zip_score','name_zip_score']
for i in cols:
    print(df[i].value_counts())
# Out:
#  1.00    83
#  0.01    12
#  0.00    11
# -1.00     6
# Name: name_city_score, dtype: int64
#  1.00    74
#  0.00    26
#  0.01     8
# -1.00     4
# Name: name_score, dtype: int64
#  1.00    87
#  0.01    13
# -1.00    11
#  0.00     1
# Name: name_city_zip_score, dtype: int64
#  1.00    71
#  0.00    28
#  0.01     9
# -1.00     4
# Name: name_zip_score, dtype: int64

# %%
df.loc[68]
# Out:
# district                                     Montgomery County Public Schools
# state                                                                      MD
# school                                                 Chevy Chase Elementary
# level                                                              Elementary
# school_link                 https://www2.montgomeryschoolsmd.org/schools/c...
# different from district?                                                    1
# learning platform?                                                        Nan
# learning platform_name                                                    Nan
# date collected                                                     03/31/2020
# pdf                                                                         0
# notes                               School Has Weekly Newsletter With Updates
# collected by                                                           Nicole
# cleaned                                         Chevy Chase Elementary School
# city                                                              Chevy Chase
# county                                                      Montgomery County
# address                                                      4015 Rosemary St
# zip                                                                     20815
# name_city_url               https://www2.montgomeryschoolsmd.org/schools/c...
# name_city_score                                                             1
# name_city_zip_url           https://www2.montgomeryschoolsmd.org/schools/n...
# name_city_zip_score                                                         0
# name_url                    https://www2.montgomeryschoolsmd.org/schools/c...
# name_score                                                                  1
# name_zip_url                https://www2.montgomeryschoolsmd.org/schools/c...
# name_zip_score                                                              1
# Name: 68, dtype: object
